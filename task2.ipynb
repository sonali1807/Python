# %% [markdown]
# ## Task 1: In built Function

# %%
x = 'in build'

# %%
print(x.casefold())
# Out:
# in build

# %%
print(x.title())
# Out:
# In Build

# %%
print(x.endswith('d'))
# Out:
# True

# %%
print(x.find('b'))
# Out:
# 3

# %% [markdown]
# # Immutability

# %%
name = "Tree"

# %%
name[0] = "F"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-00f69f9ff8e5> in <module>
# ----> 1 name[0] = "F"
#
# TypeError: 'str' object does not support item assignment

# %%
"F" +name[1:]
# Out:
# 'Free'

# %%
x = 100

# %%
x[2] = 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-8da6362b2e69> in <module>
# ----> 1 x[2] = 5
#
# TypeError: 'int' object does not support item assignment

# %% [markdown]
# # Mutable

# %%
color = ["red" , "orange" , "yellow"]

# %%
print(color)
# Out:
# ['red', 'orange', 'yellow']

# %%
color[1] = "pink"

# %%
color[-1] = "black"

# %%
print(color)
# Out:
# ['red', 'pink', 'black']
