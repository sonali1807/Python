# %% [markdown]
# # Task 5

# %%
dict1 = { 
   "april_batch":{ 
      "student":{ 
         "name":"Mike",
         "marks":{ 
            "python":80,
            "maths":70
         }
      }
   }
}

# %%
dict1["april_batch"]["student"]["name"]
# Out:
# 'Mike'

# %%
dict1["april_batch"]["student"]["marks"]["python"]
# Out:
# 80

# %%
dict1["april_batch"]["student"]["name"] = "Sonali"
dict1
# Out:
# {'april_batch': {'student': {'name': 'Sonali',
#    'marks': {'python': 80, 'maths': 70}}}}

# %%
dict1["april_batch"]["student"]["marks"]["ML"]["DL"] = "80" , "80"
dict1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-6676e2da916b> in <module>
# ----> 1 dict1["april_batch"]["student"]["marks"]["ML"]["DL"] = "80" , "80"
#       2 dict1
#
# KeyError: 'ML'
