# %% [markdown]
# ## reduce() - The reduce(fun,seq) function is used to apply a particular function passed in its argument to all of the list elements mentioned in the sequence passed along.

# %%
from functools import reduce
def sum(a, b):
    return a+b
print(reduce(sum , [1, 2, 3, 4]))
# Out:
# 10

# %% [markdown]
# ## zip() - The zip() function returns a zip object, which is an interator of tuples where the first item in each passed iterator is paired together and then the second item in each passed iterator are paired together etc.
# ## Syntax - zip(iterator1, iterator2, iterator3, .......)

# %%
a = ("micky", "doremon", "tom")

# %%
b = ("mouse", "sinchan", "jerry", "bhim")

# %%
x = zip(a , b)

# %%
print(tuple(x))
# Out:
# (('micky', 'mouse'), ('doremon', 'sinchan'), ('tom', 'jerry'))

# %% [markdown]
# ## enumerate() - The enumerate() function takes a collection (eg. a tuple) and returns it as anenumerate object.
# ## the enumerate() function adds a counter as the key of the enumerate object.
# ## Syntax - enumerate(iterable, start)

# %%
x = ('pineapple', 'mango', 'grapes')

# %%
y = enumerate(x)

# %%
print(list(y))
# Out:
# [(0, 'pineapple'), (1, 'mango'), (2, 'grapes')]
