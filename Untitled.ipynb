# %%
X = 5

# %%
X
# Out:
# 5

# %%
y=8

# %%
print(y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-d9183e048de3> in <module>
# ----> 1 print(y)
#
# NameError: name 'y' is not defined

# %%
X = 'Netzwerk'

# %%
X
# Out:
# 'Netzwerk'

# %%
X
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-14525dd6e948> in <module>
# ----> 1 X
#
# NameError: name 'X' is not defined

# %%
Y = 10

# %%
Y
# Out:
# 10

# %%
A = X+Y

# %%
A
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-7d157d7c000a> in <module>
# ----> 1 A
#
# NameError: name 'A' is not defined

# %%
A
# Out:
# 15
